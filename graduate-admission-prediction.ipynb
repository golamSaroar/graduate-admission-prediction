# %% [markdown]
# # University Admission Prediction Using Multiple Linear Regression

# %%
from google.colab import drive
drive.mount('/content/drive/')
import os
os.chdir('/content/drive/My Drive/Colab Notebooks/graduate-admission-prediction')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %% [markdown]
# ### Load Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# read the csv file 
admission_df = pd.read_csv('Admission_Predict.csv')

# %%
admission_df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  ...  CGPA  Research  Chance of Admit
# 0           1        337          118  ...  9.65         1             0.92
# 1           2        324          107  ...  8.87         1             0.76
# 2           3        316          104  ...  8.00         1             0.72
# 3           4        322          110  ...  8.67         1             0.80
# 4           5        314          103  ...  8.21         0             0.65
#
# [5 rows x 9 columns]

# %%
# Let's drop the serial no.
admission_df.drop('Serial No.', axis = 1, inplace = True) 
admission_df.head()
# Out:
#    GRE Score  TOEFL Score  University Rating  ...  CGPA  Research  Chance of Admit
# 0        337          118                  4  ...  9.65         1             0.92
# 1        324          107                  4  ...  8.87         1             0.76
# 2        316          104                  3  ...  8.00         1             0.72
# 3        322          110                  3  ...  8.67         1             0.80
# 4        314          103                  2  ...  8.21         0             0.65
#
# [5 rows x 8 columns]

# %% [markdown]
# ### Perform Exploratory Data Analysis

# %%
# checking the null values
admission_df.isnull().sum()
# Out:
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %%
# Check the dataframe information
admission_df.info();
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   GRE Score          500 non-null    int64
#  1   TOEFL Score        500 non-null    int64
#  2   University Rating  500 non-null    int64
#  3   SOP                500 non-null    float64
#  4   LOR                500 non-null    float64
#  5   CGPA               500 non-null    float64
#  6   Research           500 non-null    int64
#  7   Chance of Admit    500 non-null    float64
# dtypes: float64(4), int64(4)
# memory usage: 31.4 KB

# %%
# Statistical summary of the dataframe
admission_df.describe()
# Out:
#         GRE Score  TOEFL Score  ...    Research  Chance of Admit
# count  500.000000   500.000000  ...  500.000000        500.00000
# mean   316.472000   107.192000  ...    0.560000          0.72174
# std     11.295148     6.081868  ...    0.496884          0.14114
# min    290.000000    92.000000  ...    0.000000          0.34000
# 25%    308.000000   103.000000  ...    0.000000          0.63000
# 50%    317.000000   107.000000  ...    1.000000          0.72000
# 75%    325.000000   112.000000  ...    1.000000          0.82000
# max    340.000000   120.000000  ...    1.000000          0.97000
#
# [8 rows x 8 columns]

# %%
# Grouping by University ranking 
df_university = admission_df.groupby(by='University Rating').mean()
df_university
# Out:
#                     GRE Score  TOEFL Score  ...  Research  Chance of Admit
# University Rating                           ...
# 1                  304.911765   100.205882  ...  0.294118         0.562059
# 2                  309.134921   103.444444  ...  0.293651         0.626111
# 3                  315.030864   106.314815  ...  0.537037         0.702901
# 4                  323.304762   110.961905  ...  0.780952         0.801619
# 5                  327.890411   113.438356  ...  0.876712         0.888082
#
# [5 rows x 7 columns]

# %% [markdown]
# ### Perform Data Visualization

# %%
admission_df.hist(bins = 30, figsize = (20,20), color = 'r');

# %%
sns.pairplot(admission_df);

# %%
for i in admission_df.columns:
  sns.scatterplot(x = i, y='Chance of Admit', hue = "University Rating", hue_norm=(1,5),data= admission_df)
  plt.show()

# %%
corr_matrix = admission_df.corr()
corr_matrix
# Out:
#                    GRE Score  TOEFL Score  ...  Research  Chance of Admit
# GRE Score           1.000000     0.827200  ...  0.563398         0.810351
# TOEFL Score         0.827200     1.000000  ...  0.467012         0.792228
# University Rating   0.635376     0.649799  ...  0.427047         0.690132
# SOP                 0.613498     0.644410  ...  0.408116         0.684137
# LOR                 0.524679     0.541563  ...  0.372526         0.645365
# CGPA                0.825878     0.810574  ...  0.501311         0.882413
# Research            0.563398     0.467012  ...  1.000000         0.545871
# Chance of Admit     0.810351     0.792228  ...  0.545871         1.000000
#
# [8 rows x 8 columns]

# %%
plt.figure(figsize = (12,12))
sns.heatmap(corr_matrix, annot = True)
plt.show()
# From the correlation matrix, it can be seen that, all parameters have positive correlation with chance of getting admission in to the university.

# %% [markdown]
# ### Create Training and Testing Dataset

# %%
admission_df.columns
# Out:
# Index(['GRE Score', 'TOEFL Score', 'University Rating', 'SOP', 'LOR ', 'CGPA',
#        'Research', 'Chance of Admit'],
#       dtype='object')

# %%
X = admission_df.drop(columns = ['Chance of Admit'])
y = admission_df['Chance of Admit']

# %%
X.shape
# Out:
# (500, 7)

# %%
y.shape
# Out:
# (500,)

# %%
X = np.array(X)
y = np.array(y)

# %%
# reshaping the array from (500,) to (500, 1)
y = y.reshape(-1,1)
y.shape
# Out:
# (500, 1)

# %%
# scaling the data before training the model
from sklearn.preprocessing import StandardScaler, MinMaxScaler

scaler_x = StandardScaler()
X = scaler_x.fit_transform(X)

scaler_y = StandardScaler()
y = scaler_y.fit_transform(y)

# %%
# spliting the data in to test and train sets
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.15)

# %% [markdown]
# ### Train and Evaluate a Linear Regression Model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, accuracy_score

LinearRegression_model = LinearRegression()
LinearRegression_model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
accuracy_LinearRegression = LinearRegression_model.score(X_test, y_test)
accuracy_LinearRegression
# Out:
# 0.7133806279682318

# %% [markdown]
# ### Train and Evaluate an Artificial Neural Network

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dense, Activation, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam


optimizer = Adam()
ANN_model = keras.Sequential()
ANN_model.add(Dense(50, input_dim = 7))
ANN_model.add(Activation('relu'))
ANN_model.add(Dense(150))
ANN_model.add(Activation('relu'))
ANN_model.add(Dropout(0.5))
ANN_model.add(Dense(150))
ANN_model.add(Activation('relu'))
ANN_model.add(Dropout(0.5))
ANN_model.add(Dense(50))
ANN_model.add(Activation('linear'))
ANN_model.add(Dense(1))
ANN_model.compile(loss = 'mse', optimizer = 'adam')
ANN_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 50)                400
# _________________________________________________________________
# activation (Activation)      (None, 50)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 150)               7650
# _________________________________________________________________
# activation_1 (Activation)    (None, 150)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 150)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 150)               22650
# _________________________________________________________________
# activation_2 (Activation)    (None, 150)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 150)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 50)                7550
# _________________________________________________________________
# activation_3 (Activation)    (None, 50)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 51
# =================================================================
# Total params: 38,301
# Trainable params: 38,301
# Non-trainable params: 0
# _________________________________________________________________

# %%
ANN_model.compile(optimizer='Adam', loss='mean_squared_error')

# %%
epochs_hist = ANN_model.fit(X_train, y_train, epochs = 100, batch_size = 20, validation_split = 0.2)
# Out:
# Epoch 1/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.7076 - val_loss: 0.2268
# Epoch 2/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.3994 - val_loss: 0.2015
# Epoch 3/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.3048 - val_loss: 0.1771
# Epoch 4/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.2837 - val_loss: 0.1676
# Epoch 5/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2568 - val_loss: 0.1592
# Epoch 6/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2795 - val_loss: 0.1531
# Epoch 7/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2426 - val_loss: 0.1565
# Epoch 8/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2433 - val_loss: 0.1532
# Epoch 9/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2175 - val_loss: 0.1483
# Epoch 10/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2257 - val_loss: 0.1436
# Epoch 11/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.2316 - val_loss: 0.1528
# Epoch 12/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2273 - val_loss: 0.1540
# Epoch 13/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2266 - val_loss: 0.1447
# Epoch 14/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2148 - val_loss: 0.1587
# Epoch 15/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2451 - val_loss: 0.1573
# Epoch 16/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2085 - val_loss: 0.1607
# Epoch 17/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.1856 - val_loss: 0.1453
# Epoch 18/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2182 - val_loss: 0.1619
# Epoch 19/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1951 - val_loss: 0.1514
# Epoch 20/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.2071 - val_loss: 0.1652
# Epoch 21/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2165 - val_loss: 0.1658
# Epoch 22/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1825 - val_loss: 0.1618
# Epoch 23/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1838 - val_loss: 0.1577
# Epoch 24/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1726 - val_loss: 0.1680
# Epoch 25/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1863 - val_loss: 0.1565
# Epoch 26/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1813 - val_loss: 0.1572
# Epoch 27/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.1958 - val_loss: 0.1684
# Epoch 28/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1923 - val_loss: 0.1485
# Epoch 29/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1841 - val_loss: 0.1601
# Epoch 30/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1953 - val_loss: 0.1617
# Epoch 31/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1754 - val_loss: 0.1501
# Epoch 32/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.1958 - val_loss: 0.1759
# Epoch 33/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1794 - val_loss: 0.1510
# Epoch 34/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1666 - val_loss: 0.1597
# Epoch 35/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.1806 - val_loss: 0.1679
# Epoch 36/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.1737 - val_loss: 0.1564
# Epoch 37/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1713 - val_loss: 0.1619
# Epoch 38/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1795 - val_loss: 0.1568
# Epoch 39/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1669 - val_loss: 0.1644
# Epoch 40/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1570 - val_loss: 0.1597
# Epoch 41/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1652 - val_loss: 0.1616
# Epoch 42/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1547 - val_loss: 0.1581
# Epoch 43/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1676 - val_loss: 0.1855
# Epoch 44/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.1634 - val_loss: 0.1640
# Epoch 45/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1740 - val_loss: 0.1722
# Epoch 46/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1588 - val_loss: 0.1599
# Epoch 47/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.1681 - val_loss: 0.1789
# Epoch 48/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1298 - val_loss: 0.1674
# Epoch 49/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1696 - val_loss: 0.1566
# Epoch 50/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.1534 - val_loss: 0.1571
# Epoch 51/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1465 - val_loss: 0.1565
# Epoch 52/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1434 - val_loss: 0.1609
# Epoch 53/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1598 - val_loss: 0.1871
# Epoch 54/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1509 - val_loss: 0.1679
# Epoch 55/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1623 - val_loss: 0.1657
# Epoch 56/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.1408 - val_loss: 0.1679
# Epoch 57/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.1403 - val_loss: 0.1700
# Epoch 58/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1532 - val_loss: 0.1812
# Epoch 59/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.1594 - val_loss: 0.1853
# Epoch 60/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1643 - val_loss: 0.1981
# Epoch 61/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1431 - val_loss: 0.1722
# Epoch 62/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1617 - val_loss: 0.1833
# Epoch 63/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1739 - val_loss: 0.2055
# Epoch 64/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1649 - val_loss: 0.1818
# Epoch 65/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1442 - val_loss: 0.1724
# Epoch 66/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1438 - val_loss: 0.1722
# Epoch 67/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.1418 - val_loss: 0.1808
# Epoch 68/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.1310 - val_loss: 0.1845
# Epoch 69/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1547 - val_loss: 0.1793
# Epoch 70/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1271 - val_loss: 0.1817
# Epoch 71/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1477 - val_loss: 0.1780
# Epoch 72/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.1458 - val_loss: 0.1751
# Epoch 73/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1362 - val_loss: 0.1869
# Epoch 74/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1419 - val_loss: 0.1936
# Epoch 75/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.1363 - val_loss: 0.2026
# Epoch 76/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1407 - val_loss: 0.1867
# Epoch 77/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1231 - val_loss: 0.1951
# Epoch 78/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1176 - val_loss: 0.1871
# Epoch 79/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1370 - val_loss: 0.1879
# Epoch 80/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1262 - val_loss: 0.1821
# Epoch 81/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1255 - val_loss: 0.1819
# Epoch 82/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1079 - val_loss: 0.1861
# Epoch 83/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.1284 - val_loss: 0.1903
# Epoch 84/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1208 - val_loss: 0.2019
# Epoch 85/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.1198 - val_loss: 0.1889
# Epoch 86/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.1180 - val_loss: 0.1855
# Epoch 87/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1292 - val_loss: 0.1929
# Epoch 88/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1364 - val_loss: 0.1961
# Epoch 89/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1010 - val_loss: 0.1891
# Epoch 90/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1332 - val_loss: 0.1918
# Epoch 91/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1213 - val_loss: 0.1940
# Epoch 92/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1110 - val_loss: 0.1996
# Epoch 93/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1270 - val_loss: 0.2088
# Epoch 94/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1136 - val_loss: 0.1961
# Epoch 95/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.1113 - val_loss: 0.2044
# Epoch 96/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.1116 - val_loss: 0.2091
# Epoch 97/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1162 - val_loss: 0.1985
# Epoch 98/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1061 - val_loss: 0.2120
# Epoch 99/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.1036 - val_loss: 0.2046
# Epoch 100/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0939 - val_loss: 0.2018

# %%
result = ANN_model.evaluate(X_test, y_test)
accuracy_ANN = 1 - result
print("Accuracy : {}".format(accuracy_ANN))
# Out:
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3927
# Accuracy : 0.6073091626167297

# %%
epochs_hist.history.keys()
# Out:
# dict_keys(['loss', 'val_loss'])

# %%
plt.plot(epochs_hist.history['loss'])
plt.plot(epochs_hist.history['val_loss'])
plt.title('Model Loss Progress During Training')
plt.xlabel('Epoch')
plt.ylabel('Training and Validation Loss')
plt.legend(['Training Loss', 'Validation Loss'])

# %% [markdown]
# ### Train and Evaluate a Decision Tree and Random Forest Models

# %%
# Decision tree builds regression or classification models in the form of a tree structure. 
# Decision tree breaks down a dataset into smaller subsets while at the same time an associated decision tree is incrementally developed. 
# The final result is a tree with decision nodes and leaf nodes.
# Great resource: https://www.saedsayad.com/decision_tree_reg.htm

from sklearn.tree import DecisionTreeRegressor

DecisionTree_model = DecisionTreeRegressor()
DecisionTree_model.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=None, splitter='best')

# %%
accuracy_DecisionTree = DecisionTree_model.score(X_test, y_test)
accuracy_DecisionTree
# Out:
# 0.5339154940652129

# %%
# Many decision Trees make up a random forest model which is an ensemble model. 
# Predictions made by each decision tree are averaged to get the prediction of random forest model.
# A random forest regressor fits a number of classifying decision trees on various sub-samples of the dataset and uses averaging to improve the predictive accuracy and control over-fitting. 

from sklearn.ensemble import RandomForestRegressor

RandomForest_model = RandomForestRegressor(n_estimators=100, max_depth=10)
RandomForest_model.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=10, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
accuracy_RandomForest = RandomForest_model.score(X_test, y_test)
accuracy_RandomForest
# Out:
# 0.6664143521791943

# %% [markdown]
# ### Print KPIs For the Best Model

# %%
y_predict = LinearRegression_model.predict(X_test)
plt.plot(y_test, y_predict, "^", color = 'r')
plt.xlabel('Model Predictions')
plt.ylabel('True Values')
# Out:
# Text(0, 0.5, 'True Values')

# %%
y_predict_orig = scaler_y.inverse_transform(y_predict)
y_test_orig = scaler_y.inverse_transform(y_test)

# %%
plt.plot(y_test_orig, y_predict_orig, "^", color = 'r')
plt.xlabel('Model Predictions')
plt.ylabel('True Values')
# Out:
# Text(0, 0.5, 'True Values')

# %%
k = X_test.shape[1]
n = len(X_test)
n
# Out:
# 75

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from math import sqrt

RMSE = float(format(np.sqrt(mean_squared_error(y_test_orig, y_predict_orig)),'.3f'))
MSE = mean_squared_error(y_test_orig, y_predict_orig)
MAE = mean_absolute_error(y_test_orig, y_predict_orig)
r2 = r2_score(y_test_orig, y_predict_orig)
adj_r2 = 1-(1-r2)*(n-1)/(n-k-1)

print('RMSE =',RMSE, '\nMSE =',MSE, '\nMAE =',MAE, '\nR2 =', r2, '\nAdjusted R2 =', adj_r2)
# Out:
# RMSE = 0.076
# MSE = 0.0057026503623210986
# MAE = 0.05347029248610193
# R2 = 0.7133806279682318
# Adjusted R2 = 0.6834353204425246
